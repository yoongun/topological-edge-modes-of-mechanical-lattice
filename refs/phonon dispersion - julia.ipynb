# %%
# Install DifferentialEquations package
using Pkg
Pkg.add("DifferentialEquations")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed RuntimeGeneratedFunctions ─ v0.5.3
#    Installed URIs ────────────────────── v1.3.0
#    Installed DynamicPolynomials ──────── v0.3.19
#    Installed Sundials ────────────────── v4.5.3
#    Installed SteadyStateDiffEq ───────── v1.6.4
#    Installed DiffEqFinancial ─────────── v2.4.0
#    Installed Random123 ───────────────── v1.4.2
#    Installed DifferentialEquations ───── v6.18.0
#    Installed NLsolve ─────────────────── v4.5.1
#    Installed BandedMatrices ──────────── v0.16.10
#    Installed Latexify ────────────────── v0.15.6
#    Installed ModelingToolkit ─────────── v5.26.0
#    Installed SafeTestsets ────────────── v0.0.1
#    Installed Formatting ──────────────── v0.4.2
#    Installed DimensionalPlotRecipes ──── v1.2.0
#    Installed SparseDiffTools ─────────── v1.16.1
#    Installed MultiScaleArrays ────────── v1.8.1
#    Installed JuliaFormatter ──────────── v0.15.4
# ...

# %%
using DifferentialEquations

# %%
function particle!(ddu, u, p,t)
    ddu[1] = -(p[1] + p[2])u[1] + p[1]u[2] +
end
# Out:
# ArgumentError: Package DifferentialEquations not found in current path:
# - Run `import Pkg; Pkg.add("DifferentialEquations")` to install the DifferentialEquations package.
#
#
# Stacktrace:
#  [1] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:893
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
