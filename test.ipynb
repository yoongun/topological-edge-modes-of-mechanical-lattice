# %%
from conut import MechanicalGrapheneBulk


mg = MechanicalGrapheneBulk(κ=1, m=1, l=1, precision=1e-1)
evals, evecs = mg.forward()

# %%
import numpy as np
evals, evecs = evals.numpy(), evecs.numpy()
# 3D dispersion
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(mg.kxs, mg.kys)

vmax = np.amax(evals[:, :, 3].real)
ax.plot_surface(X, Y, evals[:, :, 1].real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 
ax.plot_surface(X, Y, evals[:, :, 2].real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 
p = ax.plot_surface(X, Y, evals[:, :, 3].real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 
ax.set_xlabel(r"$k_x$ [/m]", fontsize=14)
ax.set_xlim(-mg.lat.xw, mg.lat.xw)
ax.set_ylabel(r"$k_y$ [/m]", fontsize=14)
ax.set_ylim(-mg.lat.yw, mg.lat.yw)
ax.set_zlabel(r"$\omega$ [/s]", fontsize=14)
ax.set_zlim(0)

fig.colorbar(p, pad=0.15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14248/3599640205.py in <module>
#       1 import numpy as np
# ----> 2 evals, evecs = evals.numpy(), evecs.numpy()
#       3 # 3D dispersion
#       4 import matplotlib.pyplot as plt
#       5 fig = plt.figure()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'numpy'

# %%
import numpy as np


print(evals.shape)

# 3D dispersion
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y = np.meshgrid(mg.kxs, mg.kys)

vmax = np.amax(np.sqrt(evals[:, :, 7]).real)
# ax.plot_surface(X, Y, np.sqrt(evals[:, :, 7]).real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 
ax.plot_surface(X, Y, np.sqrt(evals[:, :, 5]).real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 
p = ax.plot_surface(X, Y, np.sqrt(evals[:, :, 6]).real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 

ax.set_xlabel(r"$k_x$ [/m]", fontsize=14)
# ax.set_xlim(-mg.h.lat.xw, mg.h.lat.xw)
ax.set_ylabel(r"$k_y$ [/m]", fontsize=14)
# ax.set_ylim(-mg.h.lat.yw, mg.h.lat.yw)
ax.set_zlabel(r"$\omega$ [/s]", fontsize=14)
# ax.set_zlim(0)

# fig.colorbar(p, pad=0.15)
# # fig.savefig("2d-graphene-dispersion-3d.png")
# plt.show()


# # Contour plot
# import matplotlib.pyplot as plt
# import matplotlib.colors as colors
# fig, ax = plt.subplots()
# X, Y = np.meshgrid(mg.kxs, mg.kys)

# vmax = np.amax(np.sqrt(evals[:, :, 2]).real)
# cs = plt.contour(X, Y, np.sqrt(evals[:, :, 2]).real, vmin=0., vmax=vmax, cmap='gist_rainbow_r') 

# plt.xlabel(r"$k_x$ [/m]",  fontsize=14)
# # plt.xlim(-xw, xw)
# plt.ylabel(r"$k_y$ [/m]", fontsize=14)
# # plt.ylim(-yw, yw)


# norm= colors.Normalize(vmin=0., vmax=vmax)
# sm = plt.cm.ScalarMappable(norm=norm, cmap=cs.cmap)
# sm.set_array([])
# fig.colorbar(sm)
# # fig.savefig("2d-graphene-dispersion-contour.png")
# plt.show()
# Out:
# (84, 73, 8)
# Text(0.5, 0, '$\\omega$ [/s]')
